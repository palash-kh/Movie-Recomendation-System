# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Read data
data = pd.read_csv('run_time.csv', header=None, names=['Method', 'Time (seconds)'])

# Plotting each method attempt vs time
fig, ax = plt.subplots(figsize=(10, 6))
for method, group in data.groupby('Method'):
    attempts = np.arange(1, len(group) + 1)
    ax.plot(attempts, group['Time (seconds)'], marker='o', label=method)

ax.set_xlabel('Attempt')
ax.set_ylabel('Time (seconds)')
ax.set_title('Method Attempt vs Time')
ax.legend()
plt.grid(True)
plt.show()

# Calculate statistics
statistics = data.groupby('Method')['Time (seconds)'].agg(['min', 'max', 'mean', 'median', 'std'])
print(statistics)
# Out:
#                                         min        max       mean     median  \
# Method
# KMeans_implementation.py          13.910237  18.587061  15.410927  14.397730
# KNN_implementation.py              1.540439   2.482073   1.721206   1.616034
# Linear_Kernel_Approach.py         56.903388  78.384806  65.693817  60.204885
# Logistic_Regression_Approach.py    1.200041  16.597044   3.010863   1.492741
# Naive_Bayes_Approach.py            2.484485   3.255709   2.812323   2.768102
# Polynomial_Kernel_Approach.py     59.129344  61.250752  59.855321  59.807297
# RBF_Kernel_Approach.py            59.679954  63.186314  61.000746  60.792124
# Random_Forrest_Implementation.py   1.493579   2.101848   1.732882   1.684045
# SVD_Approach.py                    1.639110   2.662864   2.027913   1.860608
#
#                                        std
# Method
# KMeans_implementation.py          1.838509
# KNN_implementation.py             0.288284
# Linear_Kernel_Approach.py         9.344839
# Logistic_Regression_Approach.py   4.782015
# Naive_Bayes_Approach.py           0.243505
# Polynomial_Kernel_Approach.py     0.633901
# RBF_Kernel_Approach.py            1.143934
# Random_Forrest_Implementation.py  0.188758
# SVD_Approach.py                   0.382153
